# %%
# arthemetic operations
a = 10
b = 5

add = a+b
sub = a-b
multiple = a*b
divide = a/b
floor_division = a//b
modulus = a%b

print(add)
print(sub)
print(multiple)
print(divide)
print(floor_division)
print(modulus)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0

# %%
# comparition operator
# equals to 
a = 5 
b = 5
print (a==b)
# Out:
# True

# %%
str1 = "abhi"
str2 = "Abhi"

str1 == str2
# so it is case sensitive also
# Out:
# False

# %%
# not equals to 
str1 = 'abhi'
str2 = 'Abhi'
str1 != str2
# Out:
# True

# %%
# greater than 
a = 5
b = 2

# print(a>b)
print (a<b)
# Out:
# False

# %%
# greater than or equal to
x = 45
y = 45

# print(x>=y)
# coz one of the condition is getting matched sismilarly 
print(x<=y)
# Out:
# True

# %%
# logical operators 
# and, or, not 
c = False
d = False
print(c and d)
# and returns True only if both values are True
# Out:
# False

# %%
# or 
c = False
d = True
print(c or d)
# or returns True if at least one value is True
# Out:
# True

# %%
# not 
c = False
print(not c)
# not simply reverses the value:
# Out:
# True
