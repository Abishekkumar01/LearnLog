# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("hello world")
# Out:
# hello world

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
write_something = input("how is yoru day going?")

print("reply:", write_something)
# Out:
# reply: good

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = float(input("Enter the number:"))

if num > 0:
    print ("postive number")
elif num < 0:
    print ("negative number")
else:
    print("zero")
# Out:
# postive number

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a = float(input("Enter the first number:"))
b = float(input("Enter the second number:"))
c = float(input("Enter the third number:"))
print(a,b,c)    
if a>=b and a>=c:
    print("the largerest no. is",a)
elif b>=a and b>=c:
    print("the largerest no. is",b) 
else:
    print("the largerest no. is",c)
# Out:
# 3.0 3.0 33.0
# the largerest no. is 33.0

# %%
# or method 
a = float(input("Enter the first number:"))
b = float(input("Enter the second number:"))
c = float(input("Enter the third number:"))
print(a,b,c)
print("the largest number is:",max(a,b,c))
# Out:
# 3.0 3.0 3.0
# the largest number is: 3.0

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
import math
num = int(input("Enter the number:"))
print("Factorial is:", math.factorial(num))
# Out:
# Factorial is: 6

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a = 5
b = 5.5
c = "abhi"
d = True

# print values 
print(a)
print(b)
print(c)
print(d)

# print types 
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 5
# 5.5
# abhi
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = int(input("Enter the 1st number:"))
b = int(input("Enter the 2nd number:"))

temp = a 
a = b 
b = temp

print("after swapping")
print("a =", a)
print("b =", b)
# Out:
# after swapping
# a = 3
# b = 3

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input("Enter the celsius value:"))

fahrenheit = 9/5 * celsius + 32
print("the fahrenheit value is:", fahrenheit)
# Out:
# the fahrenheit value is: 37.4

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = input("Enter the 1st String:")
str2 = input("Enter the 2nd string:")

result = str1 + str2
print(result)
# Out:
# 333

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
value = input("Enter anything: ")

try:
    value = int(value)
    print("it is int")
except:
    try:
        value = float(value)
        print("it is float")
    except:
        if value.lower() == "true" or value.lower() == "false":
            print("it is bool")
        else:
            print("it is string")
# Out:
# it is int

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = float(input("Enter the number:"))
square  = num*num
print("the sq. of the no. is:",square)
# Out:
# the sq. of the no. is: 9.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter the number:"))

if num % 2 == 0:
    print("It is even")
else:
    print("It is odd")
# Out:
# It is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
num = int(input("Enter the number:"))
sum = num*(num+1) // 2
print("the sum is", sum)
# Out:
# the sum is 561

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter the value:"))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("it is leap year")
else: 
    print("it is not leap year")
# Out:
# it is not leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
value = input("Enter the string")
reversed_str = value[::-1]
print("The reversed str is:",reversed_str)
# Out:
# The reversed str is: 33

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
value = input("Enter the text or int:")

value = str(value) # converts int to str
if value == value[::-1]:
    print("It is a palimdrome")
else: 
    print("It is not a palindrome")
# Out:
# It is a palimdrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
num = input("Enter the number").split()
print(sorted(num))
# Out:
# ['1', '10', '2', '5']
