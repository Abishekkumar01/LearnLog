# %%
# take input 
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))

# arthemetic operations 
add = num1 + num2
multiple = num1 * num2
subtract = num1 - num2
divide = num1 / num2
floor_divide = num1 // num2 
modulus = num1 % num2

# print values
print("add:", add)
print("multiple:", multiple)
print("subtract:", subtract)
print("divide:", divide)
print("floor_divide:", floor_divide)
print("modulus:", modulus)
# Out:
# add: 10.0
# multiple: 25.0
# subtract: 0.0
# divide: 1.0
# floor_divide: 1.0
# modulus: 0.0
