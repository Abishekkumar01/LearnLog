# %% [markdown]
# # Data types - Data types are the classification of data that tell the compilers and interpreter how the programer intend to use the data.
#
# # To determine the type of operations that can be performed in the data

# %%
# integer eg.
age = 21
print(type(age))
# Out:
#   Cell In[4], line 1
#     interger eg.
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# float eg.
height = 5.11
print(type(height))
# Out:
# <class 'float'>

# %%
# string eg.
name = "abhi"
print(type(name))
# Out:
# <class 'str'>

# %%
# boolean eg.
is_true = True
print (type(is_true))
# Out:
# <class 'bool'>

# %%
bool()
# Out:
# False

# %%
a = 10
b = 10
a=b
print(type(a==b))
# Out:
# <class 'bool'>

# %% [markdown]
# # Common errors

# %%
result = "Abhi" + 5 
print (result )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result = "Abhi" + 5
#       2 print (result )
#
# TypeError: can only concatenate str (not "int") to str

# %%
result2 = "Abhi" + str(5)
print(result2)
# Out:
# Abhi5
