# %%
print('hello')
# Out:
# hello

# %%
age = 50
if age < 60:
    print(age)
# Out:
# 50

# %%
totall = 2 + 2 + 2 + \
5 + 2
print (totall)
# backlash is used to totall
# Out:
#   Cell In[8], line 4
#     backlash is used to totall
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# muiltiple statement
x=5;y=5;z=x+y
print(z)
# Out:
#   Cell In[10], line 1
#     muiltiple statement
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
