# %% [markdown]
# # Pandas tutorials - Code With Harry - Notebook 1

# %%
import numpy as np 
import pandas as pd

# %%
dict1 = {
    "name":['Abishek', 'Chetan', 'Aman', 'Vrusti', 'Etti'],
    "marks":[50,40,30,45,48],
    "city":["Bangalore", "MP", "Rajasthan", "Gujarat", "Kerala"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks       city
# 0  Abishek     50  Bangalore
# 1   Chetan     40         MP
# 2     Aman     30  Rajasthan
# 3   Vrusti     45    Gujarat
# 4     Etti     48     kerala

# %%
df.to_csv('friend.csv')

# %%
df.to_csv('friend_no_index.csv', index = False)

# %%
df.describe()
# Out:
#           marks
# count   5.00000
# mean   42.60000
# std     7.98749
# min    30.00000
# 25%    40.00000
# 50%    45.00000
# 75%    48.00000
# max    50.00000

# %%
Train = pd.read_csv('Train.csv')

# %%
Train
# Out:
#    Unnamed: 0  Train  Speed       city
# 0           0  32113    503  Bangalore
# 1           1  21312    340         MP
# 2           2   1234    330  Rajasthan
# 3           3  12356    245    Gujarat
# 4           4  12455    248     kerala

# %%
Train = pd.read_csv('Train.csv', index_col = False)

# %%
Train
# Out:
#    Unnamed: 0  Train  Speed       city
# 0           0  32113    503  Bangalore
# 1           1  21312    340         MP
# 2           2   1234    330  Rajasthan
# 3           3  12356    245    Gujarat
# 4           4  12455    248     kerala

# %%
Train = Train.drop('Unnamed: 0', axis = 1)

# %%
Train
# Out:
#    Train  Speed       city
# 0  32113    503  Bangalore
# 1  21312    340         MP
# 2   1234    330  Rajasthan
# 3  12356    245    Gujarat
# 4  12455    248     kerala

# %%
Train = pd.read_csv('Train.csv', index_col = False)
