# %% [markdown]
# # **Numpy**

# %%
import numpy as np
print ("imported")
# Out:
# imported

# %%
ls = [1,2,3,4,5]
ls
# Out:
# [1, 2, 3, 4, 5]

# %%
ls = [1,2,3,4,5]
arr = np.array(ls)
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr+5
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
arr.ndim
# Out:
# 1

# %%
arr.shape
# Out:
# (5,)

# %%
arr.size
# Out:
# 5

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
ls = [6,7,8,9,10]
arr2 = np.array(ls)

# %%
ls = [1, 2, 3, 4, 5]
for i in ls:
    if i<5:
        print (i)

arr[arr<5]
# Out:
# 1
# 2
# 3
# 4
# array([1, 2, 3, 4])
